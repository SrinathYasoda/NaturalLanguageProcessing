# %%
import credentials
import json
import tweepy
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
#!pip install tweepy
#importing necessary tweepy libraries
from tweepy.streaming import StreamListener #helps us in handling incoming data
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy import API

# %%
access_token='277096430-VaZfIqjPFJ3cbRxNlWgnD7IBMSklCY8UEmWqMeHZ'
access_token_secret='dTUgaMwTC7me96slf0aIr6DtKmknHDcgHlTrU7coa4rkx'
consumer_key='QmGhW53Sn8Ss7vsegJkDgEVMP'
consumer_secret='xeaYI1i9vJUAsBJcZ8luNZQHBllCTQ46nXATTymMJu36cN4RH5'

# %%
#Setting up twitter
def twitter_setup():
    """
    Utility function to setup the twitters api
    with our access keys provided
    
    """
    auth=OAuthHandler(consumer_key,consumer_secret)
    auth.set_access_token(access_token,access_token_secret)
    api=tweepy.API(auth)
    return api

# %% [markdown]
# ## Searching Data in Twitter

# %% [markdown]
# ## Method1: User Timeline

# %%
# Twitter extraction
#lets create an extractor object
extractor=twitter_setup()

#We create tweet list as follows:
tweets=extractor.user_timeline(screen_name="realDonaldTrump",count=200)
print("Number of tweets extracter:{} \n".format(len(tweets)))
# Out:
# Number of tweets extracter:200

# %%
# print(tweets[:1])
#printing the most recent 5 tweets

print("5 recent tweents:\n")
for tweet in tweets[:5]:
    print(tweet.text)
    print()
# Out:
# 5 recent tweents:
#
# Joe Biden called Black Youth SUPER PREDATORS. They will NEVER like him, or vote for him. They are voting for “TRUMP”.
#
# ...The place was a mess and would have lost much more business if I hadn’t come along. Many new plants are starting… https://t.co/A6LbYgvQ99
#
# When I originally became your all time favorite President, the Great State of Michigan was hemorrhaging car compani… https://t.co/j66jPA1EF7
#
# Our numbers are looking VERY good all over. Sleepy Joe is already beginning to pull out of certain states. The Radical Left is going down!
#
# People have long been voting but Joe Biden has still not released his Supreme Court List of Radical Left Judges tha… https://t.co/gwojSCC9Ef

# %%
#creating pandas data frame
data=pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

#display function plots an output in a friendly way
display(data.head(10))
# Out:
#                                               Tweets
# 0  Joe Biden called Black Youth SUPER PREDATORS. ...
# 1  ...The place was a mess and would have lost mu...
# 2  When I originally became your all time favorit...
# 3  Our numbers are looking VERY good all over. Sl...
# 4  People have long been voting but Joe Biden has...
# 5  RT @GOP: “Last night, our brave Special Forces...
# 6  RT @GOP: The GREAT @CoachLouHoltz88 joined @re...
# 7  RT @GOP: "If you want a vaccine to kill the vi...
# 8  RT @GOP: “A vote for Biden and Harris is a vot...
# 9  RT @GOP: “My administration has delivered safe...

# %%
#collecting data with tweepy
# listen=SListener(api)
# stream=Stream(auth,listen)
# stream.sample()

# class SListener(StreamListener):
#     def __int__(self,api=None):
#         self.output=open('tweets_%s.json' % time.strftime('%Y%m%d-%H%M%S'),'w')
#         self.api=api or API()

        #variables that contain user credentials for accessing twitter api
# access_token='277096430-VaZfIqjPFJ3cbRxNlWgnD7IBMSklCY8UEmWqMeHZ'
# access_token_secret='dTUgaMwTC7me96slf0aIr6DtKmknHDcgHlTrU7coa4rkx'
# consumer_key='QmGhW53Sn8Ss7vsegJkDgEVMP'
# consumer_secret='xeaYI1i9vJUAsBJcZ8luNZQHBllCTQ46nXATTymMJu36cN4RH5'

# class StdOutListner(StreamListener):
#     def on_date(self,data):
#         print (data)
#         return True
    
#     def on_error(self,status):
#         print (status)

# if __name__=='__main__':
#     I=StdOutListner()
#     auth=OAuthHandler(consumer_key,consumer_secret)
#     auth.set_access_token(access_token,access_token_secret)
#     stream=Stream(auth,I)
    
#     stream.filter(track=['python','javascript','ruby'])

# %%
#Internal methods of a single tweet object
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1322885492933799936
# 2020-11-01 12:57:34
# Twitter for iPhone
# 23526
# 4558
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}

# %%
# Adding relevant information into the dataframe
#import numpy as np
data['len']=np.array([len(tweet.text) for tweet in tweets])
data['ID']=np.array([tweet.id for tweet in tweets])
data['Date']=np.array([tweet.created_at for tweet in tweets])
data['Source']=np.array([tweet.source for tweet in tweets])
data['Likes']=np.array([tweet.favorite_count for tweet in tweets])
data['ReTweeCou']=np.array([tweet.retweet_count for tweet in tweets])

# %%
#display(data.head(10))

# %% [markdown]
# ## 2 .Cursor() methodd

# %%
import tweepy
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy import API

# %%
import pandas
import numpy
import os

# %%
access_token='277096430-VaZfIqjPFJ3cbRxNlWgnD7IBMSklCY8UEmWqMeHZ'
access_token_secret='dTUgaMwTC7me96slf0aIr6DtKmknHDcgHlTrU7coa4rkx'
consumer_key='QmGhW53Sn8Ss7vsegJkDgEVMP'
consumer_secret='xeaYI1i9vJUAsBJcZ8luNZQHBllCTQ46nXATTymMJu36cN4RH5'

def twittersetup():
    auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
    auth.set_access_token(access_token,access_token_secret)
    api=tweepy.API(auth)
    return api

# %%
search_words="#BigBossTelugu4"
data_since="2020-08-30"

# %%
#extract data using twitter
extractor=twittersetup()
tweets=tweepy.Cursor(extractor.search,
                    q=search_words,
                    lang="en",
                    since=data_since).items(100)

tweets

# %%
for tweet in tweets:
    print(tweet.text)
# Out:
# @FruitSpreads @sujavarunee “We all need people who will give us feedback. That’s how we improve.” Thank you so much… https://t.co/OviYtasfj2
# RT @starlingpayal: Dussehra special 💃
# Today at 6pm on @starmaa 🌟
#
# May all your troubles end this Dussehra! Sending you good wishes and peac…
# RT @starlingpayal: You are the most beautiful soul I’ve ever met ...Thank you for making my day super special and memorable 🥰
# @Samanthaprab…
# 😂😂😂😂😂..damage has been done ..#Avinash becoming more irritating with his promos #BigBossTelugu4 #Abijeet #Noel… https://t.co/kEWfTucNla
# RT @Deepthi23236216: Too much asalu vere topic ye ledha.. epudu monal medhane...
# #AskBiggBoss  #bigbosstelugu4 https://t.co/t81AIfLNVr
# RT @priya13059006: #Ariyana for the win 🔥🔥🔥#BigbossTelugu4 #Biggboss4telugu https://t.co/EIqjbf5YpC
# RT @iPradeepthinks: Two new words we can learn &amp; own from #BigBossTelugu4 from 2 contestants i.e.,                             Kumar Sai: S…
# RT @Kittuga1: #bigbosstelugu4
# ...

# %%
new_search=search_words+"-filter:retweets"

tweets=tweepy.Cursor(extractor.search,
                    q=new_search,
                    lang="en",
                    since=data_since).items(30)

for tw in tweets:
    print(tw.text)
# Out:
# @FruitSpreads @sujavarunee “We all need people who will give us feedback. That’s how we improve.” Thank you so much… https://t.co/OviYtasfj2
# 😂😂😂😂😂..damage has been done ..#Avinash becoming more irritating with his promos #BigBossTelugu4 #Abijeet #Noel… https://t.co/kEWfTucNla

# %%
#who is tweeting about wildfires
#Tweeting about Noshave
#sw="#noshave"
data_since="2018-04-23"
#ns=sw+"-filter:retweets"

# %%
newSe="climate+change -filter:retweets"
ts=tweepy.Cursor(extractor.search,
                q=newSe,
                lang="en",
                since=data_since).items(1000)

# %%
alltweets=[i.text for i in ts]
alltweets
# Out:
# ['Former New York City mayor Michael Bloomberg gave $2.5 million to a Democratic candidate for the Texas Railroad Com… https://t.co/cVXqIW2mWX',
#  'People never notice climate change.',
#  'Watching the health sector resign to the climate change alarm strategy has been cool. “There are hotspots raging al… https://t.co/hV7qxlof9s',
#  'Iris Stop utilizes internet video and memes to critique climate change through a software tool targeted at national decision makers.',
#  'Covid 19 pandemic cannot wipe out humanity,but climate change will be the greatest threat to the survival of mankin… https://t.co/ggq5t0D88p',
#  '@wef @1t_org @WEFUpLink Its a temporary fix...the local climate environment will change too quickly for natural spe… https://t.co/6rp3JiXk0A',
#  'I find this fucking devastating. And Biden doesn’t believe in stopping climate change. https://t.co/CfoDZLOYb2',
# ...

# %% [markdown]
# ## Streaming Data From Twitter

# %%
import tweepy 
from tweepy.streaming import StreamListener
from tweepy import Stream
from tweepy import OAuthHandler
import MySQLdb
